# %%
import sqlite3
import pandas as pd
import re
import pickle
import progressbar

# %%
path=r'indices.pickle'
nPath = path.replace(' ', '\\ ')
with open (path , 'rb') as file:
    authors=pickle.load(file)

# %%
authors
# Out:
# [[0],
#  [1],
#  [2],
#  [3, 1735809],
#  [4],
#  [5],
#  [6],
#  [7],
#  [8,
#   2036318,
#   2089849,
#   2089895,
#   2091885,
#   2137812,
#   2151172,
#   2152992,
#   2219873,
#   2219954,
#   2223562,
#   2225611,
#   2227139,
#   2244727],
#  [9],
#  [10,
#   1209699,
#   1212063,
#   1213317,
#   1213654,
#   1213806,
#   1213956,
#   1214015,
#   1214031,
#   1214121,
#   1214210,
#   1214309,
#   1214381,
#   1214509,
#   1214705,
#   1214784,
#   1214833,
#   1214958,
#   1215238,
#   1215275,
#   1215370,
#   1215549,
#   1215863,
#   1216157,
#   1216249,
#   1216433,
#   1216558,
#   1217953,
#   1220025,
#   1220911,
#   1221291,
#   1221417,
#   1225505,
#   1236253,
#   1238045,
#   1243309,
#   1247892,
#   1248150,
#   1248324,
#   1252894,
#   1253311,
#   1253364,
#   1254630,
#   1255079,
#   1256224,
#   1263665,
#   1264292,
#   1264464,
#   1268356,
#   1268873,
#   1268905,
#   1268979,
#   1269030,
#   1269143,
#   1269157,
#   1269274,
#   1269386,
# ...

# %%
! ls Training/Data
# Out:
# x_test_new_1517827.pickle
# x_test_new_1519362.pickle
# x_test_new_1519374.pickle
# x_test_new_1520689.pickle
# x_test_new_1520908.pickle
# x_test_new_reshuffeled_1517827.pickle
# x_test_new_reshuffeled_1519362.pickle
# x_test_new_reshuffeled_1519374.pickle
# x_test_new_reshuffeled_1520689.pickle
# x_test_new_reshuffeled_1520908.pickle
# x_train_new_1517827.pickle
# x_train_new_1519362.pickle
# x_train_new_1519374.pickle
# x_train_new_1520689.pickle
# x_train_new_1520908.pickle
# x_train_new_reshuffeled_1517827.pickle
# x_train_new_reshuffeled_1519362.pickle
# x_train_new_reshuffeled_1519374.pickle
# x_train_new_reshuffeled_1520689.pickle
# x_train_new_reshuffeled_1520908.pickle
# x_validate_new_1517827.pickle
# x_validate_new_1519362.pickle
# x_validate_new_1519374.pickle
# x_validate_new_1520689.pickle
# x_validate_new_1520908.pickle
# x_validate_new_reshuffeled_1517827.pickle
# x_validate_new_reshuffeled_1519362.pickle
# x_validate_new_reshuffeled_1519374.pickle
# ...
